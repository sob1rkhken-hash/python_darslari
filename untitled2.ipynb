# %% [markdown]
# <a href="https://colab.research.google.com/github/sob1rkhken-hash/python_darslari/blob/newest/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('22.csv')

# %%
print(df.head())

print(df.columns)

print(df.describe())
# Out:
#                          species  year     variable    units magnitude  \
# 0  Alfonsino & Long-finned Beryx  1996  Asset value  Dollars  Millions
# 1  Alfonsino & Long-finned Beryx  1996         TACC   Tonnes    Actual
# 2  Alfonsino & Long-finned Beryx  1997  Asset value  Dollars  Millions
# 3  Alfonsino & Long-finned Beryx  1997         TACC   Tonnes    Actual
# 4  Alfonsino & Long-finned Beryx  1998  Asset value  Dollars  Millions
#
#                    source  data_value flag
# 0  Environmental Accounts        20.3  NaN
# 1  Environmental Accounts      2721.9  NaN
# 2  Environmental Accounts        32.6  NaN
# 3  Environmental Accounts      2721.1  NaN
# 4  Environmental Accounts        31.2  NaN
# Index(['species', 'year', 'variable', 'units', 'magnitude', 'source',
#        'data_value', 'flag'],
#       dtype='object')
#               year     data_value
# count  5333.000000    5086.000000
# mean   2010.115320    8955.347778
# std       5.854674   52514.213218
# ...
